# %%
temp = 21

# %%
site_name = "Santa Barbara"

# %%
temp
# Out:
# 21

# %%
description = """
This dataset records daily air temperatire at three stations.
This demonstrates that you can create a long sting using double quotes 
before and after a series of words.
"""

# %%
count = 42          # an int
rainfall = 3.5      # a float (default for decimal)

# %%
type(rainfall) # calls atomic type
# Out:
# float

# %%
### Dot Notation ###
# type(description) # str
description.upper() # variable followed by a "." 
# prompts a series of functions, i.e. "upper()" returning uppercase

# In R, you usually call a function on an object by upper(description)
# In Python, you call a method on object by description.upper()
# Out:
# '\nTHIS DATASET RECORDS DAILY AIR TEMPERATIRE AT THREE STATIONS.\nTHIS DEMONSTRATES THAT YOU CAN CREATE A LONG STING USING DOUBLE QUOTES \nBEFORE AND AFTER A SERIES OF WORDS.\n'

# %%
high_temp = 24
low_temp = 12
temp_range = high_temp - low_temp
temp_range
# Out:
# 12

# %%
# Print() statement
print(high_temp)
print(low_temp)
print("Temperature Range =", temp_range)

# temp_range.print() 
# Returns, AttributeError: 'int' object has no attribute 'print'
# Out:
# 24
# 12
# Temperature Range = 12

# %%
# f-strings
name = "Kelly"
print(f"Hello, {name}!") # f function calls whatever variable is in brackets
# Out:
# Hello, Kelly!

# %%
# f strings can include multiple variables
print(f"The low was {low_temp} and the high was {high_temp} in {site_name}.")

# f strings also take arithmetic
print(f"The temperature range was {high_temp - low_temp}.")
# Out:
# The low was 12 and the high was 24 in Santa Barbara.
# The temperature range was 12.
