# %% [markdown]
# # Day 3: Session 3B - The Filter Pattern
# ### df_filtered = df[df['column'] > x]
#
# [Session Webpage](https://eds-217-essential-python.github.io/course-materials/interactive-sessions/3b_filtering_data.html)
#
# Date: 09/02/2026

# %%
import pandas as pd

url = 'https://eds-217-essential-python.github.io/data/openaq_goleta_measurments.csv'
goleta = pd.read_csv(url)
goleta.shape
# Out:
# (1962, 15)

# %%
goleta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1962 entries, 0 to 1961
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   location_id    1962 non-null   int64
#  1   location_name  1962 non-null   object
#  2   parameter      1962 non-null   object
#  3   value          1962 non-null   float64
#  4   unit           1962 non-null   object
#  5   datetimeUtc    1962 non-null   object
#  6   datetimeLocal  1962 non-null   object
#  7   timezone       1962 non-null   object
#  8   latitude       1962 non-null   float64
#  9   longitude      1962 non-null   float64
#  10  country_iso    0 non-null      float64
#  11  isMobile       0 non-null      float64
#  12  isMonitor      0 non-null      float64
#  13  owner_name     1962 non-null   object
#  14  provider       1962 non-null   object
# dtypes: float64(6), int64(1), object(8)
# memory usage: 230.1+ KB

# %%
## **FILTERING** ##
# IN SIMPLE TERMS 
# filtering is creating a list of true/falses,
# passing that list back into your dataframe,
# and then seeing what returns true

keep_col = goleta['value'] > 20
gt_20 = goleta[keep_col]
gt_20.describe()
# Out:
#        location_id       value      latitude     longitude  country_iso  \
# count        115.0  115.000000  1.150000e+02  1.150000e+02          0.0
# mean        1186.0   25.373913  3.444530e+01 -1.198278e+02          NaN
# std            0.0    4.288829  7.136523e-15  2.854609e-14          NaN
# min         1186.0   21.000000  3.444530e+01 -1.198278e+02          NaN
# 25%         1186.0   22.000000  3.444530e+01 -1.198278e+02          NaN
# 50%         1186.0   24.000000  3.444530e+01 -1.198278e+02          NaN
# 75%         1186.0   27.000000  3.444530e+01 -1.198278e+02          NaN
# max         1186.0   40.000000  3.444530e+01 -1.198278e+02          NaN
#
#        isMobile  isMonitor
# count       0.0        0.0
# mean        NaN        NaN
# std         NaN        NaN
# min         NaN        NaN
# 25%         NaN        NaN
# 50%         NaN        NaN
# 75%         NaN        NaN
# max         NaN        NaN

# %%
# gt_20 has the same output as 
goleta[goleta['value'] > 20] # generic filter pattern
# df_filtered = df[df['column'] > x]
# also a filter method
# ?goleta.filter

# %%
# goleta['parameter'].value_counts()
ozone = goleta[(goleta['parameter'] == 'o3')]
ozone.shape
# Out:
# (711, 15)

# %%
pm25 = goleta[(goleta['parameter'] == 'pm25')]
print(pm25.shape)
print(goleta['parameter'].value_counts())
# Out:
# (734, 15)
# parameter
# pm25    734
# o3      711
# pm10    517
# Name: count, dtype: int64

# %%
# Combining logical operators !
goleta_filtered = (goleta[(
    goleta['parameter'] == 'pm25'
    ) & (
        goleta['value'] > 9
        )]) 
goleta_filtered
# Out:
#       location_id location_name parameter  value   unit  \
# 1261         1186        Goleta      pm25   14.0  µg/m³
# 1265         1186        Goleta      pm25   10.0  µg/m³
# 1270         1186        Goleta      pm25   10.0  µg/m³
# 1313         1186        Goleta      pm25   12.0  µg/m³
# 1314         1186        Goleta      pm25   11.0  µg/m³
# ...           ...           ...       ...    ...    ...
# 1953         1186        Goleta      pm25   16.0  µg/m³
# 1954         1186        Goleta      pm25   16.0  µg/m³
# 1955         1186        Goleta      pm25   13.0  µg/m³
# 1956         1186        Goleta      pm25   14.0  µg/m³
# 1957         1186        Goleta      pm25   10.0  µg/m³
#
#                     datetimeUtc              datetimeLocal  \
# 1261  2024-07-13T10:00:00+00:00  2024-07-13T03:00:00-07:00
# 1265  2024-07-13T14:00:00+00:00  2024-07-13T07:00:00-07:00
# 1270  2024-07-13T19:00:00+00:00  2024-07-13T12:00:00-07:00
# ...

# %%
# Negation in pandas world (~ "tilda")

print("Output: ", (goleta['parameter'] == 'pm25'))
print("Output flipped with tilda: ", ~(goleta['parameter'] == 'pm25')) # flip it
# Out:
# Output:  0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1957     True
# 1958     True
# 1959     True
# 1960     True
# 1961     True
# Name: parameter, Length: 1962, dtype: bool
# Output flipped with tilda:  0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1957    False
# 1958    False
# 1959    False
# 1960    False
# 1961    False
# Name: parameter, Length: 1962, dtype: bool

# %%
# Writing (col == 'a') | (col == 'b') | (col == 'c') gets tedious fast. 
# .isin() takes a list and matches any of its members:
particulates = goleta[goleta['parameter'].isin(['pm25', 'pm10'])]
particulates.describe()
# 🐍 Call .isin() on the column, not on the DataFrame: df['col'].isin([...]). 
# .isin() returns a mask, exactly like a comparison does, 
# so it goes in the same place inside the brackets.
# ?particulates.isin
# Out:
#        location_id        value     latitude     longitude  country_iso  \
# count       1251.0  1251.000000  1251.000000  1.251000e+03          0.0
# mean        1186.0     9.990408    34.445301 -1.198278e+02          NaN
# std            0.0     6.919647     0.000000  1.421654e-14          NaN
# min         1186.0    -4.000000    34.445301 -1.198278e+02          NaN
# 25%         1186.0     5.000000    34.445301 -1.198278e+02          NaN
# 50%         1186.0     8.000000    34.445301 -1.198278e+02          NaN
# 75%         1186.0    14.000000    34.445301 -1.198278e+02          NaN
# max         1186.0    40.000000    34.445301 -1.198278e+02          NaN
#
#        isMobile  isMonitor
# count       0.0        0.0
# mean        NaN        NaN
# std         NaN        NaN
# min         NaN        NaN
# 25%         NaN        NaN
# 50%         NaN        NaN
# 75%         NaN        NaN
# max         NaN        NaN
